# %%
import tensorflow as tf

# %%
input = tf.keras.Input(shape=(32,))
b1 = tf.keras.layers.Dense(10,activation='relu')(input)
b2 = tf.keras.layers.Dense(10,activation='relu')(input)
b3 = tf.keras.layers.Dense(10,activation='relu')(input)
b4 = tf.keras.layers.Dense(10,activation='relu')(input)
merge = 
model = tf.keras.Model(inputs=input,outputs=x)

tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True, to_file='base-model.png')
